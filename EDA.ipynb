# %%
import pandas as pd 
import numpy as np 
import matplotlib.pylab as plt
import seaborn as sns

# %%
df = pd.read_csv('total_dataset.csv')

# %%
# Data Understanding
df.shape
df.isna().sum()
# Out:
# side                                  68643
# range_type                            68643
# volume_of_trades                      68643
# strike                                    0
# expiration_date                           0
# right                                     0
# options_close_price                       0
# options_volume                            0
# count                                     0
# bid                                       0
# bid_size                                  0
# ask                                       0
# ask_size                                  0
# open_interest                           660
# delta                                     0
# theta                                     0
# vega                                      0
# rho                                       0
# epsilon                                   0
# lambda                                    0
# gamma                                     0
# d1                                        0
# d2                                        0
# implied_vol                               0
# iv_error                                  0
# stock_close                               0
# stock_high                                0
# stock_low                                 0
# stock_open                                0
# stock_traded_volume                       0
# divCash                                   0
# reported_estimate_eps_percent_diff        0
# vix-open                                  0
# vix-high                                  0
# vix-low                                   0
# vix-close                                 0
# pos_em_count                          69194
# neg_em_count                          69194
# em_total_count                        69194
# pos_nem_count                         69194
# neu_em_count                          69194
# neu_nem_count                         69194
# neg_nem_count                         69194
# nem_total_count                       69194
# pos_total_count                       69194
# neu_total_count                       69194
# neg_total_count                       69194
# total_count                           69194
# article_sentiment                     69194
# article_count                         69194
# dtype: int64

# %%
df.duplicated().sum() # 591 duplicated values
df.loc[df.duplicated()]
# Out:
#       side range_type  volume_of_trades  strike expiration_date right  \
# 38892  NaN        NaN               NaN    89.0          7 days     C
# 38894  NaN        NaN               NaN   100.0          7 days     C
# 38896  NaN        NaN               NaN   101.0          7 days     C
# 38898  NaN        NaN               NaN   102.5          7 days     C
# 38900  NaN        NaN               NaN   104.0          7 days     C
# ...    ...        ...               ...     ...             ...   ...
# 39674  NaN        NaN               NaN   140.0         21 days     C
# 39675  NaN        NaN               NaN   145.0         21 days     C
# 39676  NaN        NaN               NaN   145.0         21 days     C
# 39677  NaN        NaN               NaN   150.0         21 days     C
# 39678  NaN        NaN               NaN   150.0         21 days     C
#
#        options_close_price  options_volume  count    bid  ...  neu_em_count  \
# 38892                34.26              20      5  32.00  ...           NaN
# 38894                23.06              76     26  21.75  ...           NaN
# 38896                21.82              66      3  20.60  ...           NaN
# 38898                19.94              41     21  18.40  ...           NaN
# 38900                19.00              14      2  17.75  ...           NaN
# ...                    ...             ...    ...    ...  ...           ...
# 39674                 0.15              40     15   0.12  ...           NaN
# 39675                 0.08              33     12   0.06  ...           NaN
# 39676                 0.08              33     12   0.06  ...           NaN
# 39677                 0.05              74     13   0.03  ...           NaN
# 39678                 0.05              74     13   0.03  ...           NaN
#
#        neu_nem_count  neg_nem_count  nem_total_count  pos_total_count  \
# 38892            NaN            NaN              NaN              NaN
# 38894            NaN            NaN              NaN              NaN
# 38896            NaN            NaN              NaN              NaN
# 38898            NaN            NaN              NaN              NaN
# 38900            NaN            NaN              NaN              NaN
# ...              ...            ...              ...              ...
# 39674            NaN            NaN              NaN              NaN
# 39675            NaN            NaN              NaN              NaN
# 39676            NaN            NaN              NaN              NaN
# 39677            NaN            NaN              NaN              NaN
# 39678            NaN            NaN              NaN              NaN
#
#        neu_total_count  neg_total_count  total_count  article_sentiment  \
# 38892              NaN              NaN          NaN                NaN
# 38894              NaN              NaN          NaN                NaN
# 38896              NaN              NaN          NaN                NaN
# 38898              NaN              NaN          NaN                NaN
# 38900              NaN              NaN          NaN                NaN
# ...                ...              ...          ...                ...
# 39674              NaN              NaN          NaN                NaN
# 39675              NaN              NaN          NaN                NaN
# 39676              NaN              NaN          NaN                NaN
# 39677              NaN              NaN          NaN                NaN
# 39678              NaN              NaN          NaN                NaN
#
#        article_count
# 38892            NaN
# 38894            NaN
# 38896            NaN
# 38898            NaN
# 38900            NaN
# ...              ...
# 39674            NaN
# 39675            NaN
# 39676            NaN
# 39677            NaN
# 39678            NaN
#
# [591 rows x 50 columns]

# %%
 df.head(100)
# Out:
#    side range_type  volume_of_trades  strike expiration_date right  \
# 0   NaN        NaN               NaN   105.0         10 days     C
# 1   NaN        NaN               NaN   106.0         10 days     C
# 2   NaN        NaN               NaN   107.0         10 days     C
# 3   NaN        NaN               NaN   107.0         24 days     C
# 4   NaN        NaN               NaN   107.5         10 days     C
# ..  ...        ...               ...     ...             ...   ...
# 95  NaN        NaN               NaN   124.0         10 days     C
# 96  NaN        NaN               NaN   124.0         24 days     C
# 97  NaN        NaN               NaN   124.5         10 days     C
# 98  NaN        NaN               NaN   125.0         10 days     C
# 99  NaN        NaN               NaN   125.0         24 days     C
#
#     options_close_price  options_volume  count    bid  ...  neu_em_count  \
# 0                 10.55              56     14  10.35  ...           NaN
# 1                 10.60              11      2   7.95  ...           NaN
# 2                  8.10              27      4   8.00  ...           NaN
# 3                  9.60              85      9   7.80  ...           NaN
# 4                  8.20              27      8   6.50  ...           NaN
# ..                  ...             ...    ...    ...  ...           ...
# 95                 0.15             261     25   0.13  ...           NaN
# 96                 0.85              23      4   0.65  ...           NaN
# 97                 0.14              40     22   0.11  ...           NaN
# 98                 0.10             138     35   0.09  ...           NaN
# 99                 0.56             389     57   0.51  ...           NaN
#
#     neu_nem_count  neg_nem_count  nem_total_count  pos_total_count  \
# 0             NaN            NaN              NaN              NaN
# 1             NaN            NaN              NaN              NaN
# 2             NaN            NaN              NaN              NaN
# 3             NaN            NaN              NaN              NaN
# 4             NaN            NaN              NaN              NaN
# ..            ...            ...              ...              ...
# 95            NaN            NaN              NaN              NaN
# 96            NaN            NaN              NaN              NaN
# 97            NaN            NaN              NaN              NaN
# 98            NaN            NaN              NaN              NaN
# 99            NaN            NaN              NaN              NaN
#
#     neu_total_count  neg_total_count  total_count  article_sentiment  \
# 0               NaN              NaN          NaN                NaN
# 1               NaN              NaN          NaN                NaN
# 2               NaN              NaN          NaN                NaN
# 3               NaN              NaN          NaN                NaN
# 4               NaN              NaN          NaN                NaN
# ..              ...              ...          ...                ...
# 95              NaN              NaN          NaN                NaN
# 96              NaN              NaN          NaN                NaN
# 97              NaN              NaN          NaN                NaN
# 98              NaN              NaN          NaN                NaN
# 99              NaN              NaN          NaN                NaN
#
#     article_count
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 95            NaN
# 96            NaN
# 97            NaN
# 98            NaN
# 99            NaN
#
# [100 rows x 50 columns]

# %%
df.columns
# Out:
# Index(['side', 'range_type', 'volume_of_trades', 'strike', 'expiration_date',
#        'right', 'options_close_price', 'options_volume', 'count', 'bid',
#        'bid_size', 'ask', 'ask_size', 'open_interest', 'delta', 'theta',
#        'vega', 'rho', 'epsilon', 'lambda', 'gamma', 'd1', 'd2', 'implied_vol',
#        'iv_error', 'stock_close', 'stock_high', 'stock_low', 'stock_open',
#        'stock_traded_volume', 'divCash', 'reported_estimate_eps_percent_diff',
#        'vix-open', 'vix-high', 'vix-low', 'vix-close', 'pos_em_count',
#        'neg_em_count', 'em_total_count', 'pos_nem_count', 'neu_em_count',
#        'neu_nem_count', 'neg_nem_count', 'nem_total_count', 'pos_total_count',
#        'neu_total_count', 'neg_total_count', 'total_count',
#        'article_sentiment', 'article_count'],
#       dtype='object')

# %%
df.dtypes
# Out:
# side                                   object
# range_type                             object
# volume_of_trades                      float64
# strike                                float64
# expiration_date                        object
# right                                  object
# options_close_price                   float64
# options_volume                          int64
# count                                   int64
# bid                                   float64
# bid_size                                int64
# ask                                   float64
# ask_size                                int64
# open_interest                         float64
# delta                                 float64
# theta                                 float64
# vega                                  float64
# rho                                   float64
# epsilon                               float64
# lambda                                float64
# gamma                                 float64
# d1                                    float64
# d2                                    float64
# implied_vol                           float64
# iv_error                              float64
# stock_close                           float64
# stock_high                            float64
# stock_low                             float64
# stock_open                            float64
# stock_traded_volume                     int64
# divCash                               float64
# reported_estimate_eps_percent_diff    float64
# vix-open                              float64
# vix-high                              float64
# vix-low                               float64
# vix-close                             float64
# pos_em_count                          float64
# neg_em_count                          float64
# em_total_count                        float64
# pos_nem_count                         float64
# neu_em_count                          float64
# neu_nem_count                         float64
# neg_nem_count                         float64
# nem_total_count                       float64
# pos_total_count                       float64
# neu_total_count                       float64
# neg_total_count                       float64
# total_count                           float64
# article_sentiment                     float64
# article_count                         float64
# dtype: object

# %%
df.describe()
# Out:
#        volume_of_trades        strike  options_close_price  options_volume  \
# count      1.872600e+04  87369.000000         87369.000000    87369.000000
# mean       2.642255e+10    130.670939             4.895354     1694.757935
# std        3.266463e+10     31.360659             9.462747     5064.130643
# min        3.973194e+06      5.000000             0.010000       11.000000
# 25%        7.683405e+09    107.000000             0.190000       48.000000
# 50%        1.642964e+10    127.500000             1.890000      190.000000
# 75%        3.371613e+10    146.000000             5.020000      903.000000
# max        5.143397e+11    340.000000           151.200000   175838.000000
#
#               count           bid      bid_size           ask      ask_size  \
# count  87369.000000  87369.000000  87369.000000  87369.000000  87369.000000
# mean     253.228548      4.687320     98.575261      5.116804     96.264808
# std      692.536009      9.237739    143.733956      9.692602    256.355525
# min        1.000000      0.000000      0.000000      0.010000      1.000000
# 25%       12.000000      0.160000     20.000000      0.220000     20.000000
# 50%       38.000000      1.780000     52.000000      2.000000     50.000000
# 75%      155.000000      4.800000    111.000000      5.300000     97.000000
# max    20265.000000    149.800000   3063.000000    152.100000  40374.000000
#
#        open_interest  ...  neu_em_count  neu_nem_count  neg_nem_count  \
# count   86709.000000  ...  18175.000000   18175.000000   18175.000000
# mean     3303.497826  ...      7.032297       6.898982       7.148501
# std      6233.585404  ...     14.656561      11.842415      12.223309
# min         0.000000  ...      0.000000       0.000000       0.000000
# 25%       297.000000  ...      0.000000       1.000000       0.000000
# 50%       959.000000  ...      2.000000       3.000000       2.000000
# 75%      3137.000000  ...      6.000000       8.000000       7.000000
# max    107929.000000  ...    127.000000      81.000000      87.000000
#
#        nem_total_count  pos_total_count  neu_total_count  neg_total_count  \
# count     18175.000000     18175.000000     18175.000000     18175.000000
# mean         22.785805        15.405667        13.931279        11.810234
# std          39.578639        30.322249        25.882132        20.658613
# min           0.000000         0.000000         0.000000         0.000000
# 25%           2.000000         1.000000         1.000000         1.000000
# 50%           6.000000         3.000000         5.000000         3.000000
# 75%          27.000000        16.000000        14.000000        13.000000
# max         295.000000       237.000000       208.000000       158.000000
#
#         total_count  article_sentiment  article_count
# count  18175.000000       18175.000000   18175.000000
# mean      41.147180           0.019807       0.346520
# std       75.343531           0.189244       2.782391
# min        0.000000           0.000000       0.000000
# 25%        5.000000           0.000000       0.000000
# 50%       10.000000           0.000000       0.000000
# 75%       44.000000           0.000000       0.000000
# max      603.000000           2.000000      31.000000
#
# [8 rows x 46 columns]

# %%
## Feature Understanding
df['strike'].value_counts().plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.pairplot(df, vars=['volume_of_trades', 'strike', 'options_close_price', 'options_volume', 'count',
       'bid_size', 'ask_size', 'iv_error','stock_traded_volume',
        'vix-high', 'vix-close',  'total_count',
       'article_sentiment', 'article_count'], diag_kind='kde', kind = 'reg', plot_kws={'line_kws':{'color':'red'}})
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_corr = df[[ 'volume_of_trades',  'options_volume',
       'bid_size', 'ask_size', 'vix-close',  'total_count',
       'article_sentiment',]].dropna().corr()

# %%
sns.heatmap(df_corr, annot = True)
# Out:
# <Axes: >
